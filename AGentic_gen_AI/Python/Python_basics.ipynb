# %%
# we write the all the notes in Notebook #Python Notebook 
""" Variables """ 
1. What is a variable 
2. Each variable must be stored in memory so that the value can be called from memory 
3. So that value can be called from memory 
4. Eery time you must need to define the value with variable 
5.
# Out:
# ' Variables '

# %% [markdown]
# # python variable introduction

# %%
v = 5 # inmemoery shores the value in 5 
v
# Out:
# 5

# %%
"""
5 = v
"" # this won't work beacuase it's a syntex erorr  --> comes under compile time error 
# wine user write some code if any mistake  happendf from user then those error's comes User forgot error

print(5)
v = 5
# Out:
#   Cell In[7], line 1
#     5 = v  # this won't work beacuase it's a syntex erorr  --> comes under compile time error
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
6  # we can pass the direct variable but
# Out:
# 6

# %% [markdown]
# #rules to define python variables

# %%
# the rules is 
V1=5
V1
v1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 V1=5
#       3 V1
# ----> 4 v1
#
# NameError: name 'v1' is not defined

# %%
# rules of of the python variables 
lowe case and upper case --> case sensitive
# Out:
#   Cell In[14], line 2
#     lowe case and upper case --> case sensitive
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# variabled does not start with digit or number but variable can end's with Digit

# %%
23a = 56 # it comes with error
# Out:
#   Cell In[15], line 1
#     23a = 56 # it comes with error
#      ^
# SyntaxError: invalid decimal literal

# %%
a23 = 56 
a23
# Out:
# 56

# %%
nit@ =45
# Out:
#   Cell In[18], line 1
#     nit@ =45
#          ^
# SyntaxError: invalid syntax

# %%
""" special character Should not contain in the variables's """
# Out:
# " special character Should not contain in the variables's "

# %%
Special characters cann't define as variable except underScore _
# Out:
#   Cell In[22], line 1
#     Special characters cann't define as variable except underScore _
#                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# 4th rule
# --> special words reserved words are not declare as keyword

# %%
import keyword 
keyword.  # to build math project Do not ask question's to update an resume , you get job
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
Over all we have 35 keywords 
C had some keywords the fact is the then Python will complete the 
if you know all the keywords --> Python will compplee

# %%
1. Variables case senstive 
2. Does not start with digit 
3. special character not allowd 
4. only _ is allowed 
5. keyword or reserved word 
6. what is function and argument & fn without argument 
7. variable & function 
8. introduce to keyword as well 
9. print == > print the statement's 
10.
=== function ==== 

    variable vs functions 
    function ends with()

# %%
family = 45 # family is variable define the value 45 
car() --> car functin 
car(bmw, audi, merui) --> cars function with 3 argument or 3 parameters 
funtion () with argument or without argument
cars(b, a , m ) cars with 3 argument

cat gpt model traner 4.5 bllion parameters 
a

# %%
 # float divsiion 
print(10/5 )
# int division 
print(10 // 5 )
# Out:
# 2.0
# 2

# %%
a = 56 
print(a)
# Out:
# 56

# %%
""" vakue = datatype 
number == interger(int)
decimal = float
bool ()
complex ()
string() """
# Out:
# ' vakue = datatype \nnumber == interger(int)\ndecimal = float\nbool ()\ncomplex ()\nstring() '
