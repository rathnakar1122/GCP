# %%
x = (5 > 3 and 5 < 10)

print(x)
# Out:
# True

# %%
x = (5 > 3 ad 5 < 10) 
print(x)
# Out:
#   Cell In[2], line 1
#     x = (5 > 3 ad 5 < 10)
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
